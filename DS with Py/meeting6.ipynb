# %%
import pandas as pd

# %%
data = {
    'Nama': ['Riska', 'Alya', 'Budi'],
    'Usia': [20, 22, 21],
    'Kota': ['Jakarta', 'Bandung', 'Surabaya']
}

df = pd.DataFrame(data)

print(df)
# Out:
#     Nama  Usia      Kota
# 0  Riska    20   Jakarta
# 1   Alya    22   Bandung
# 2   Budi    21  Surabaya

# %%
myDataSet = {
    'name': ['riska', 'kejo', 'shlawa'],  
    'age': [20, 21, 19]  
} #dict

df = pd.DataFrame(myDataSet)

print(myDataSet)
print(df)
# Out:
# {'name': ['riska', 'kejo', 'shlawa'], 'age': [20, 21, 19]}
#      name  age
# 0   riska   20
# 1    kejo   21
# 2  shlawa   19

# %%
myData = { 'ID' :['01','02','03','04','05','06'],
          'FirstName': ['riska', 'shlawa', 'kejo', 'bima', 'graces', 'akil'],
          'LastName': ['atikah', 'sakina', 'josep', 'sena', 'febri', 'faslah'],
          'major' : ['is', 'ir', 'act', 'law', 'it', 'id']}

d = pd.DataFrame(myData)

print(d)
# Out:
#    ID FirstName LastName major
# 0  01     riska   atikah    is
# 1  02    shlawa   sakina    ir
# 2  03      kejo    josep   act
# 3  04      bima     sena   law
# 4  05    graces    febri    it
# 5  06      akil   faslah    id

# %%
#Series
data = [10,11,12]

a = pd.Series(data, index=['a','b','c'])

print(data)
print(a)
print(a[0])
print(a['b'])
# Out:
# [10, 11, 12]
# a    10
# b    11
# c    12
# dtype: int64
# 10
# 11
# C:\Users\Asus\AppData\Local\Temp\ipykernel_2520\4181239524.py:7: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   print(a[0])

# %%
x = pd.read_csv('sales.csv')

print(x.to_string())
# Out:
#       sales_id  order_id  product_id  price_per_unit  quantity  total_price
# 0            0         1         218             106         2        212.0
# 1            1         1         481             118         1        118.0
# 2            2         1           2              96         3        288.0
# 3            3         1        1002             106         2        212.0
# 4            4         1         691             113         3        339.0
# 5            5         1         981             106         3        318.0
# 6            6         2         915              96         1         96.0
# 7            7         2         686             113         1        113.0
# 8            8         2        1091             115         3        345.0
# 9            9         2        1196             105         1          NaN
# 10          10         2         157              91         3        273.0
# ...

# %%
#Get summary statistics

x = pd.read_csv('sales.csv')

print(x.describe())
# Out:
#           sales_id     order_id   product_id  price_per_unit    quantity  \
# count  5000.000000  5000.000000  5000.000000     5000.000000  5000.00000
# mean   2499.500000   503.038200   634.053200      103.501600     1.99240
# std    1443.520003   285.964418   363.255794        9.195004     0.80751
# min       0.000000     1.000000     1.000000       90.000000     1.00000
# 25%    1249.750000   258.000000   323.000000       95.000000     1.00000
# 50%    2499.500000   504.500000   635.000000      102.000000     2.00000
# 75%    3749.250000   749.000000   951.000000      112.000000     3.00000
# max    4999.000000   999.000000  1259.000000      119.000000     3.00000
#
#        total_price
# count  4981.000000
# mean    206.307368
# std      86.352449
# min      90.000000
# 25%     112.000000
# 50%     204.000000
# 75%     285.000000
# max     357.000000

# %%
#Check for missing values

x = pd.read_csv('sales.csv')

print(x.isnull().sum())
# Out:
# sales_id           0
# order_id           0
# product_id         0
# price_per_unit     0
# quantity           0
# total_price       19
# dtype: int64

# %%
#Show number of rows & columns

x = pd.read_csv('sales.csv')

print(x.shape)
# Out:
# (5000, 6)

# %%
#Get info about DataFrame

x = pd.read_csv('sales.csv')

print(x.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5000 entries, 0 to 4999
# Data columns (total 6 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   sales_id        5000 non-null   int64
#  1   order_id        5000 non-null   int64
#  2   product_id      5000 non-null   int64
#  3   price_per_unit  5000 non-null   int64
#  4   quantity        5000 non-null   int64
#  5   total_price     4981 non-null   float64
# dtypes: float64(1), int64(5)
# memory usage: 234.5 KB
# None

# %%
#Show column names

x = pd.read_csv('sales.csv')

print(x.columns)
# Out:
# Index(['sales_id', 'order_id', 'product_id', 'price_per_unit', 'quantity',
#        'total_price'],
#       dtype='object')

# %%
# Membaca hanya kolom "product_id" dan "price_per_unit" dari file sales.csv
df = pd.read_csv("sales.csv", usecols=["product_id", "price_per_unit"])

# Menampilkan DataFrame
print(df.to_string())
# Out:
#       product_id  price_per_unit
# 0            218             106
# 1            481             118
# 2              2              96
# 3           1002             106
# 4            691             113
# 5            981             106
# 6            915              96
# 7            686             113
# 8           1091             115
# 9           1196             105
# 10           157              91
# 11          1174              99
# 12            54             104
# 13             6              96
# 14          1010             106
# 15          1033              90
# 16          1184              99
# 17           769             109
# 18           923              96
# 19            12              96
# 20           148              91
# 21           475             118
# 22             1              96
# 23           830             117
# 24          1209             105
# 25           635              93
# 26           639              93
# ...

# %%
y = pd.read_csv("sales.csv", header=None)
print(y.to_string())
# Out:
#              0         1           2               3         4            5
# 0     sales_id  order_id  product_id  price_per_unit  quantity  total_price
# 1            0         1         218             106         2          212
# 2            1         1         481             118         1          118
# 3            2         1           2              96         3          288
# 4            3         1        1002             106         2          212
# 5            4         1         691             113         3          339
# 6            5         1         981             106         3          318
# 7            6         2         915              96         1           96
# 8            7         2         686             113         1          113
# 9            8         2        1091             115         3          345
# 10           9         2        1196             105         1          NaN
# ...
